# %%
import pathlib
import tensorflow as tf
data_dir = pathlib.Path('dataset')
val_dir = pathlib.Path('dataval')

batch_size = 3
image_height = 101
image_width = 101

train_data = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(image_height, image_width),
    batch_size=batch_size
)

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(image_height, image_width),
    batch_size=batch_size
)
# Out:
# Found 136 files belonging to 3 classes.
# Using 109 files for training.
# Found 15 files belonging to 3 classes.
# Using 12 files for training.

# %%
#import matplotlib.pyplot as plt
from tensorflow.keras import layers

class_names = val_data.class_names
#plt.figure(figsize=(10, 10))
#for images, labels in train_data.take(1):
#    for i in range(3):
#        ax = plt.subplot(1, 3, i+1)
#        plt.imshow(images[i].numpy().astype("uint8"))
#        plt.title(class_names[labels[i]])
#        plt.axis("off")

num_classes = 3

# CREATE CNN
model = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255),
    layers.Conv2D(128, 4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(16, 4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# COMPILE CNN
model.compile(optimizer='adam', loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %%
# Tensorboard
import keras
logdir = "logs"
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1, write_images=logdir, embeddings_metadata=train_data)

# %%
model.fit(
    train_data,
    validation_data=val_data,
    epochs=20,
    callbacks=[tensorboard_callback]
)
# Out:
# Epoch 1/20
# 37/37 [==============================] - 57s 1s/step - loss: 1.1152 - accuracy: 0.3104 - val_loss: 1.0980 - val_accuracy: 0.3333
# Epoch 2/20
# 37/37 [==============================] - 57s 2s/step - loss: 1.0981 - accuracy: 0.2751 - val_loss: 1.0972 - val_accuracy: 0.4167
# Epoch 3/20
# 37/37 [==============================] - 60s 2s/step - loss: 1.0999 - accuracy: 0.3343 - val_loss: 1.0988 - val_accuracy: 0.3333
# Epoch 4/20
# 37/37 [==============================] - 60s 2s/step - loss: 1.0959 - accuracy: 0.4116 - val_loss: 1.0990 - val_accuracy: 0.3333
# Epoch 5/20
# 37/37 [==============================] - 59s 2s/step - loss: 1.0925 - accuracy: 0.4324 - val_loss: 1.0983 - val_accuracy: 0.3333
# Epoch 6/20
# 37/37 [==============================] - 60s 2s/step - loss: 1.1003 - accuracy: 0.4346 - val_loss: 1.0992 - val_accuracy: 0.4167
# Epoch 7/20
# 37/37 [==============================] - 60s 2s/step - loss: 1.0954 - accuracy: 0.3192 - val_loss: 1.0995 - val_accuracy: 0.3333
# Epoch 8/20
# 37/37 [==============================] - 59s 2s/step - loss: 1.0972 - accuracy: 0.2533 - val_loss: 1.0993 - val_accuracy: 0.3333
# Epoch 9/20
# 37/37 [==============================] - 60s 2s/step - loss: 1.0926 - accuracy: 0.3551 - val_loss: 1.0997 - val_accuracy: 0.3333
# Epoch 10/20
# 37/37 [==============================] - 62s 2s/step - loss: 1.0934 - accuracy: 0.3311 - val_loss: 1.0995 - val_accuracy: 0.3333
# Epoch 11/20
# 37/37 [==============================] - 63s 2s/step - loss: 1.0928 - accuracy: 0.3012 - val_loss: 1.0997 - val_accuracy: 0.3333
# Epoch 12/20
# 37/37 [==============================] - 65s 2s/step - loss: 1.0917 - accuracy: 0.3207 - val_loss: 1.1000 - val_accuracy: 0.3333
# Epoch 13/20
# 37/37 [==============================] - 66s 2s/step - loss: 1.0953 - accuracy: 0.3056 - val_loss: 1.1000 - val_accuracy: 0.3333
# Epoch 14/20
# 37/37 [==============================] - 66s 2s/step - loss: 1.0967 - accuracy: 0.3369 - val_loss: 1.1002 - val_accuracy: 0.3333
# Epoch 15/20
# 37/37 [==============================] - 66s 2s/step - loss: 1.0926 - accuracy: 0.3470 - val_loss: 1.1001 - val_accuracy: 0.3333
# Epoch 16/20
# 37/37 [==============================] - 67s 2s/step - loss: 1.0890 - accuracy: 0.3406 - val_loss: 1.1004 - val_accuracy: 0.3333
# Epoch 17/20
# 37/37 [==============================] - 68s 2s/step - loss: 1.0904 - accuracy: 0.3443 - val_loss: 1.1003 - val_accuracy: 0.3333
# Epoch 18/20
# 37/37 [==============================] - 67s 2s/step - loss: 1.0926 - accuracy: 0.3104 - val_loss: 1.0997 - val_accuracy: 0.3333
# Epoch 19/20
# 37/37 [==============================] - 68s 2s/step - loss: 1.0951 - accuracy: 0.2907 - val_loss: 1.0999 - val_accuracy: 0.3333
# Epoch 20/20
# 37/37 [==============================] - 68s 2s/step - loss: 1.0961 - accuracy: 0.3007 - val_loss: 1.1001 - val_accuracy: 0.3333

# %%
# VOIR L'INTGRALITE DU CNN
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 101, 101, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 98, 98, 128)       6272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        131136
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 32)        32800
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 16)          8208
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                9280
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 187,891
# Trainable params: 187,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
import cv2

#video = cv2.VideoCapture(0)
#facedetect = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#while True:
#    ret,frame=video.read()
#    faces=facedetect.detectMultiScale(frame, 1.3, 5)
#    for x,y,w,h in faces:
#        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,0), 3)
#    cv2.imshow("WidowFrame", frame)
#    if cv2.waitKey(1) == ord('q'):
#        break
#video.release()
#cv2.destroyAllWindows()

# %%
import numpy as np

image_to_predict = cv2.imread('./testset/tf.png')
plt.imshow(cv2.cvtColor(image_to_predict, cv2.COLOR_BGR2RGB))
image_to_predict = np.expand_dims(cv2.resize(image_to_predict, (101, 101)), axis=0)
#res = model.predict_classes(image_to_predict)
print(model.predict(image_to_predict))
#model.predict(image_to_predict)
class_names[np.argmax(model.predict(image_to_predict), axis=-1)[0]]
# Out:
# [[0.34348217 0.34881386 0.3077039 ]]
# 'olivia'
